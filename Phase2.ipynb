# %% [markdown]
# ## Summary of the dataset:

# %%
import pandas as pd
df = pd.read_csv("/content/Housing.csv")

# %% [markdown]
# **Data Info:**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# **Numerical Summary:**

# %%
 df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# By analyzing the statistical measures of the dataset's attributes, we gathered the following insights:
#
# **Price:** The price of houses ranges **from 1,750,000 to 13,300,000**, with a median of **4,340,000**. This indicates a skew towards higher prices, as the 3rd quartile is much closer to the median than the maximum value, suggesting potential outliers at the higher end.
#
# **Area:** House sizes vary **from 1,650 to 16,200** square feet, with a median of **4,600** square feet. This suggests that there are more larger houses compared to smaller ones in the dataset.
#
# **Bedrooms:** The number of bedrooms ranges **from 1 to 6**, with a median of **3**, this implies that most houses have three or fewer bedrooms, with fewer homes having more than that.
#
# **Bathrooms:** The dataset shows a range of **1 to 4** bathrooms per house, with a median of **1**, indicating that most homes have just one bathroom.
#
# **Stories:** Houses in this dataset have **between 1 and 4** stories, with a median of **2**, meaning that the majority of homes have two or fewer stories.
#
# **Parking:** The number of parking spots ranges **from 0 to 3**, with a median of **0**. This suggests that most houses in the dataset likely do not have parking facilities.

# %% [markdown]
# **Variance:**
#
# indicates how dispersion and spread of values.Therefore, our variance results indicate:
#
# price have high variance, so the level of dispersion and spread of values is high.
#
# stories have low variance, so the level of dispersion and spread of values is low.

# %%
df.var(numeric_only=True)
# Out:
# price        3.498544e+12
# area         4.709512e+06
# bedrooms     5.447383e-01
# bathrooms    2.524757e-01
# stories      7.525432e-01
# parking      7.423300e-01
# dtype: float64

# %% [markdown]
# **Categorical Summary:**

# %%
df.describe(include=[object])
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %% [markdown]
# By analyzing dataset's Categorical attributes, we gathered the following insights:
#
# **mainroad:** The majority of the houses in this dataset are **located on a main road**, with **468 out of 545** properties having this feature. This shows that being near a main road is **common** in this dataset, likely offering convenience and accessibility.
#
# **guestroom:** Most houses do not have a guestroom, as **448** properties show **no** for this feature. This might suggest that having a guestroom is considered more of a **luxury or less common** in this set of houses.
#
# **basement:** Basements are also **less common**, with only **354** properties lacking one. This could be influenced by regional preferences or property type.
#
# **hotwaterheating:** The vast majority of homes do not have hot water heating, with **520** properties showing **no**. This suggests that either the homes use alternative heating methods or that hot water heating is **less of a priority** in this dataset.
#
# **airconditioning:** Air conditioning isn't widely present, with **373** homes **not having** it. This might reflect the climate of the area or the age of the properties, where air conditioning isn't a standard feature.
#
# **prefarea:** Only **128** homes are located in a **preferred area**, as most **417** homes are not. This could suggest a broader variety of locations and property types, with the majority not being classified as premium locations.
#
# **furnishingstatus:** Furnishing is a mix, but the **most common** option is **semi-furnished**, with **227** homes in this category. This could appeal to buyers looking for flexibility between a fully furnished home and an empty one.

# %% [markdown]
# **Missing Values:**
#
# there are no missing values

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# ## Data Visualization:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Scatter plot:
# Is a type of data visualization that displays individual data points on **two-dimensional** graph. Each point represents the values of two variables, one plotted along the x-axis and the other along the y-axis. Scatter plots are useful for visually identifying patterns, relationships, or trends between two continuous variables.

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x='area', y='price', data= df)
plt.title('Scatter Plot of Area vs Price')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Area vs Price')

# %% [markdown]
# **Scatter Plot Analysis:**
#
# The plot compares the relationship between price (y-axis) and area (x-axis).The points on the graph form a pattern that rises from the bottom left to the top right, indicating a **positive correlation**. As the area increases, the price also tends to increase.In Conclusion there is a strong positive relationship between the two attributes. As the area of a property grows, its price also increases, suggesting that these two factors are closely linked.

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(data=df, x='prefarea', y='price')

# Add labels and title
plt.title('Effect of Preferred Area on Price')
plt.xlabel('Preferred Area')
plt.ylabel('Price')
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# **Scatter Plot Analysis:**
#
# The plot compares the relationship between price **y-axis** and proffered area **x-axis**.As the graph provide when the proffered area is **yes** the price slightly **increased** ,and when the proffered area is **no** the price  slightly **decreased**. But the majority have the same average of price.

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x='bedrooms',y='price',data=df)
plt.title('Scatter plot of price and how the number of bedrooms effect it')
# Out:
# Text(0.5, 1.0, 'Scatter plot of price and how the number of bedrooms effect it')

# %% [markdown]
# **Scatter Plot Analysis:**
#
# The plot compares the relationship between price **y-axis** and bedrooms **x-axis**.Houses with the range between **3-4** bedrooms have the most higher prices **8-12** million. Houses with **2** bedrooms have most frequent with lower price range **2-6**.

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x='parking',y='price',data=df)
plt.title('Scatter plot of price and how the number of parking effect it')
# Out:
# Text(0.5, 1.0, 'Scatter plot of price and how the number of parking effect it')

# %% [markdown]
# **Scatter Plot Analysis:**
#
# The plot compares the relationship between price **y-axis** and parkin **x-axis**. Houses with the **2** parking spot have the most **higher** prices .Houses with **0** parking have  most frequent with **lower** price .

# %% [markdown]
# ## 2. Histogram:
#
# A histogram is a graphical representation that illustrates the distribution of **numerical data** by organizing values into **specified intervals**, known as bins. Each bin corresponds to a range of values, and the height of the bars indicates the frequency of data points within that range. This visualization helps to identify patterns, such as skewness or modality in the data, making it easier to understand the underlying distribution, detect outliers, and summarize key characteristics of the dataset. Histograms are widely used in statistics and data analysis for their effectiveness in conveying the shape and spread of data.

# %%
plt.figure(figsize=(10, 9))
plt.hist(df['price'], bins=range(int(df['price'].min()), int(df['price'].max()) + 1000000, 1000000),
         color='yellow', edgecolor='black')

plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('count')

plt.show()

# %% [markdown]
# The histogram categorizes price values into **bins** with a width of **1,000,000**, such as the range **from 5 million to 6 million**. We chose this bin width due to the **extensive price range**, which spans **from 1,750,000 to 13,300,000**. The distribution is **positively skewed**, meaning it has a longer right tail. This skewness suggests that prices below **10 million** are less likely to occur, as most of the data points cluster in the lower range, making high values increasingly rare.

# %% [markdown]
# ## 3. Bar plot:
#
# A bar plot, also referred to as a bar chart or bar graph, is a popular data visualization tool that represents **categorical data** through rectangular bars. Each bar corresponds to a specific category, with its height (or length) indicating the value or frequency associated with that category. Bar plots offer a straightforward and intuitive way to visualize data, making it easy to discern patterns, trends, and variations across different categories. They are commonly utilized to display counts, frequencies, percentages, or other metrics related to distinct categories, enhancing data comprehension.

# %%
b = df['furnishingstatus'].value_counts()
percentages = (b / b.sum() * 100).round(3)


txt = [f'{name}\n{percent}%' for name, percent in zip(b.index, percentages)]


colors = ['lightblue', 'lightgreen', 'lightpink']
bb = b.plot(kind='bar', color=colors, title='Furnishing Status', ylabel='Frequency')


for idx, value in enumerate(b):
    plt.text(idx, value / 2, txt[idx], ha='center', fontsize=9)


plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# We created a bar plot to illustrate the distribution of furnishing status across three categories: **furnished, semi-furnished, and unfurnished**. Among these, **semi-furnished** is the most prevalent, comprising **41.7%** of the dataset, which is nearly half of all entries. The other two categories are relatively close in frequency, indicating a diverse distribution of values within the dataset. This spread suggests that while semi-furnished properties dominate, furnished and unfurnished options also hold significant shares.

# %% [markdown]
# ## 4. Missing Values:
# refer to the absence of data in one or more fields within a dataset. These can occur due to data entry errors, incomplete data collection, or system failures. Handling missing values is crucial in data analysis, as they can skew results or lead to errors if not addressed properly through methods like imputation or removal.

# %%
missing_values = df.isna()
missing_counts = missing_values.sum();
rows_with_missing = df[df.isna().any(axis=1)];
print("Missing values in each column:");
print(missing_counts);
print("\nRows with missing values:");
print(rows_with_missing);
# Out:
# Missing values in each column:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64
#
# Rows with missing values:
# Empty DataFrame
# Columns: [price, area, bedrooms, bathrooms, stories, mainroad, guestroom, basement, hotwaterheating, airconditioning, parking, prefarea, furnishingstatus]
# Index: []

# %% [markdown]
# we checked for missing values in the dataset using isna() and found none. We then printed the count of missing values per column and identified any rows containing missing data.

# %% [markdown]
# ## 5. Dublicates Values:
# are records in a dataset that appear more than once, either completely identical or with repeated key fields. They often arise due to data entry errors, merging datasets, or accidental duplication during collection. Removing or managing duplicates is essential to ensure data accuracy and avoid biased analysis results.

# %%
num_duplicates = df.duplicated().sum()
print("Number of duplicate rows:", num_duplicates)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# we used the duplicated() method to check for duplicate rows in the dataset and found none. The total number of duplicate rows was printed as 0, confirming no duplicates were present.

# %% [markdown]
# ## 6. Detect Outliers:
# Detecting outliers involves identifying data points that significantly deviate from the majority of the dataset. Outliers can occur due to variability in the data, errors, or rare events, and they can distort statistical analyses or model performance.

# %%
import numpy as np

def count_outliers(data):
    outliers_count_per_column = {}

    numeric_columns = data.select_dtypes(include=[np.number]).columns

    for column in numeric_columns:
        Q1 = data[column].quantile(0.25)
        Q3 = data[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers_count = ((data[column] < lower_bound) | (data[column] > upper_bound)).sum()
        outliers_count_per_column[column] = outliers_count
    total_outliers = sum(outliers_count_per_column.values())

    return outliers_count_per_column, total_outliers


outliers_count_per_column, total_outliers = count_outliers(data)


print("Outliers per column:", outliers_count_per_column)
print("Total outliers:", total_outliers)
# Out:
# Outliers per column: {'price': 15, 'area': 12, 'bedrooms': 12, 'bathrooms': 1, 'stories': 41, 'parking': 12}
# Total outliers: 93

# %% [markdown]
# we calculated the number of outliers in each numeric column using the IQR method and stored the results. The total number of outliers across all columns was also computed and printed.

# %% [markdown]
# ## 6. Boxplts:
# are a graphical representation of the distribution of a dataset, showing the median, quartiles, and potential outliers. The box represents the interquartile range (IQR), where 50% of the data lies, with a line inside the box marking the median. Whiskers extend to show the range of the data, and any points outside the whiskers are considered outliers.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_boxplots(data):

    numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns

    for column in numeric_columns:
        plt.figure(figsize=(8, 4))
        sns.boxplot(data[column])
        plt.title(f"Boxplot of {column}")
        plt.xlabel(column)
        plt.show()

plot_boxplots(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %% [markdown]
# we created boxplots for each numeric column in the dataset using Seaborn to visualize the distribution and detect outliers. Each plot displays the range, median, and potential outliers for the respective column.

# %% [markdown]
# ## 6. Handling Outliers:
# involves identifying and addressing data points that significantly differ from the rest of the dataset, as they can skew analysis results. Common techniques include removing outliers, capping them to the nearest non-outlier values, or transforming the data to reduce their impact. Properly managing outliers is crucial for improving model accuracy and ensuring reliable statistical conclusions.

# %%
import pandas as pd

outlier_threshold = 1.5

def count_outliers_and_cap(column_data, threshold=1.5):
    Q1 = column_data.quantile(0.25)
    Q3 = column_data.quantile(0.75)
    IQR = Q3 - Q1

    upper_bound = Q3 + threshold * IQR
    lower_bound = Q1 - threshold * IQR

    outliers = (column_data > upper_bound) | (column_data < lower_bound)
    outlier_count = outliers.sum()

    capped_column = column_data.clip(lower=lower_bound, upper=upper_bound)

    return capped_column, outlier_count

outlier_counts = {}
total_rows = len(data)
numeric_columns = data.select_dtypes(include=[np.number]).columns

for column in numeric_columns:
    capped_column, outliers = count_outliers_and_cap(data[column], threshold=outlier_threshold)

    data[column] = capped_column

    outlier_counts[column] = outliers
    data.to_csv('Housing_cleaned.csv', index=False)

# %% [markdown]
#  we defined a function to count and cap outliers in each numeric column of the dataset using the IQR method. The capped values replaced the original data, and the cleaned dataset was then saved to a new CSV file, Housing_cleaned.csv.

# %%
data1 = pd.read_csv("/content/Housing_cleaned.csv")

def count_outliers(data1):
    outliers_count_per_column = {}

    numeric_columns = data1.select_dtypes(include=[np.number]).columns

    for column in numeric_columns:
        Q1 = data1[column].quantile(0.25)
        Q3 = data1[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers_count = ((data1[column] < lower_bound) | (data1[column] > upper_bound)).sum()
        outliers_count_per_column[column] = outliers_count
    total_outliers = sum(outliers_count_per_column.values())

    return outliers_count_per_column, total_outliers


outliers_count_per_column, total_outliers = count_outliers(data)


print("Outliers per column:", outliers_count_per_column)
print("Total outliers:", total_outliers)
# Out:
# Outliers per column: {'price': 0, 'area': 0, 'bedrooms': 0, 'bathrooms': 0, 'stories': 0, 'parking': 0}
# Total outliers: 0

# %% [markdown]
# We performed this step again on the new cleaned data to verify that the outlier handling was effective and that any remaining outliers were properly accounted for. This ensures the dataset's integrity and confirms that the data preprocessing steps improved the overall quality of the data.
